# %% [markdown]
# # Part 1 — Data Loading (Loaders)
# ### Understanding how to load and prepare data for LLM pipelines
#
# This notebook introduces document loaders, supported formats, and best practices for preparing data before processing it with LLM applications.

# %% [markdown]
# ## Learning Guide
#
# In this notebook, you will learn:
#
# - What document loaders are and why they are essential in LLM workflows
# - Different types of built-in loaders in LangChain
# - Best practices when handling text data from various file formats
# - How to load and inspect documents through hands-on examples
#
# This is a foundational step for building Retrieval-Augmented Generation (RAG) systems and other LLM applications requiring document ingestion.

# %%
from secrete_key import my_gemini_api_key
API_KEY = my_gemini_api_key()

print("API Key loaded successfully.")
# Out:
# API Key loaded successfully.

# %% [markdown]
# ## 1.1 What Are Loaders?
#
# Document loaders read raw data from files or URLs and convert them into a structured format suitable for LLM pipelines.
#
# Supported formats include:
#
# - PDF
# - Text files
# - Word documents
# - HTML pages
# - CSV files
# - Websites
#
# Loaders provide standardized input so that downstream steps—splitting, embedding, retrieval—operate smoothly.

# %% [markdown]
# ## 1.2 Built-in Loaders in LangChain
#
# Commonly used document loaders:
#
# - `PyPDFLoader` — Extracts text from PDF files
# - `TextLoader` — Reads plain text files
# - `WebBaseLoader` — Fetches and processes website content
# - `CSVLoader` — Loads structured CSV data
#
# Each loader outputs a list of `Document` objects containing text and metadata.
#
# <a href="https://docs.langchain.com/oss/python/integrations/document_loaders">
#   LangChain Document Loaders docs
# </a>

# %% [markdown]
# ## 1.3 Best Practices for Data Loading
#
# - Clean text to remove noise, whitespace, or unnecessary characters
# - Validate file encoding before processing
# - Use lazy loading when dealing with large datasets
# - Inspect metadata to track document source and structure

# %% [markdown]
# ## 1.4 Hands-On Demo
#
# Below is an example using common loaders.
# Upload files like `example.txt` or `example.pdf` before running the demo cells.

# %%
pip install langchain_community pypdf
# Out:
# Requirement already satisfied: langchain_community in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (0.4.1)
# Requirement already satisfied: pypdf in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (6.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (1.1.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (0.4.56)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain_community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\selvam sabarish\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\selvam sabarish\appdata\local\python\pythoncore-3.12-64\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import PyPDFLoader, TextLoader

# Example: Load a text file
try:
    loader = TextLoader("example.txt")
    docs = loader.load()
    print("Loaded text documents:", docs[:1])
except Exception as e:
    print("TextLoader example skipped:", e)
# Out:
# Loaded text documents: [Document(metadata={'source': 'example.txt'}, page_content='Force majeure, French for "superior force," is a contractual provision designed to protect parties from liability when extraordinary, unforeseeable events beyond their reasonable control prevent them from fulfilling their obligations. Such events, often called "acts of God," can include natural disasters (earthquakes, floods, hurricanes), as well as human-caused disruptions like wars, strikes, pandemics, or government actions. To successfully invoke force majeure, the affected party typically must demonstrate that the event was unforeseeable, external, and rendered performance impossible or illegal, not merely more difficult or expensive')]

# %%
# Example: Load a PDF file
try:
    loader_pdf = PyPDFLoader("Contract_doc_1pages.pdf")
    pdf_docs = loader_pdf.load()
    print("First PDF page snippet:", pdf_docs[0].page_content[:200])
except Exception as e:
    print("PyPDFLoader example skipped:", e)
# Out:
# First PDF page snippet: 28
# AIRLIFT
# 14.1 Should the BUYER intend to airlift all or some of the stores the SELLER shall pack
# the stores accordingly on  receipt of intimation to that effect from the BUYER. Such
# deliveries

# %%
from datetime import datetime

print("System Time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# System Time: 2025-12-08 10:15:39
