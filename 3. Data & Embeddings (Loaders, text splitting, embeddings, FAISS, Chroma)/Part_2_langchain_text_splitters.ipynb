# %% [markdown]
# # Part 2 — Text Splitting
# ### Techniques for creating processable text chunks for LLM pipelines
#
# This notebook explains why text splitting is essential for LLM applications and demonstrates how to split documents into meaningful segments using LangChain utilities.

# %% [markdown]
# ## Learning Guide
#
# **What you will learn**
# - Why text splitting is essential for LLM pipelines and RAG systems.
# - How different LangChain text splitters work and when to choose them.
# - Hands-on examples splitting a sample contract-like text and inspecting chunk sizes and overlaps.
#
# **Why it matters**
# - Proper chunking prevents token-overflow, preserves clause boundaries in legal docs, and improves retrieval relevance.
#
# **How it fits into an AI/LLM course**
# - Foundational step in ingestion pipelines used before embedding, indexing, or LLM prompting.
#
# **Hands-on steps you'll perform**
# 1. Install dependencies (LangChain).
# 2. Load a sample contract text and run four splitters.
# 3. Inspect chunks and evaluate which splitter best preserves legal clauses.
# 4. Save recommended configs for production ingestion.

# %%
# API Key input (kept intentionally simple per your spec)
from secrete_key import my_gemini_api_key
API_KEY = my_gemini_api_key()

# NOTE: Replace `secrete_key` / function as appropriate in your environment.
print("API_KEY loaded (hidden).")
# Out:
# API_KEY loaded (hidden).

# %% [markdown]
# # Part 2 — Text Splitting
# ### Techniques for creating processable text chunks for LLM pipelines
#
# This section demonstrates LangChain splitters and why they matter for contract documents where clause integrity is important.

# %%
# !pip install langchain-text-splitters tiktoken langchain_google_genai
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (1.0.0)
# Requirement already satisfied: tiktoken in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (0.12.0)
# Requirement already satisfied: langchain_google_genai in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (3.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-text-splitters) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.12.0)
# Requirement already satisfied: certifi in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain_google_genai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (6.33.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.6.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.6.1)

# %%
# Install LangChain in Colab / local environment if needed
# Uncomment the following line in Colab or local environment if LangChain is not installed
# !pip install --upgrade langchain
print('Ensure langchain is installed in your environment.')
# Out:
# Requirement already satisfied: langchain in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain) (1.1.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.14)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.6.0)
# Ensure langchain is installed in your environment.

# %%
# Sample contract-like text for demonstration
sample_contract = """
SERVICE AGREEMENT

This Service Agreement ("Agreement") is made as of January 1, 2024, by and between Alpha Corp ("Provider") and Beta LLC ("Client").
1. Services. Provider shall provide software development services (the "Services") described in Schedule A.
2. Term. The term of this Agreement begins on the Effective Date and continues for twelve (12) months, unless earlier terminated.
3. Payment. Client will pay Provider the fees set forth in Schedule B within thirty (30) days of invoice receipt.
4. Confidentiality. Each party shall maintain confidential information in strict confidence and not disclose it to third parties.
5. Liability. Neither party shall be liable for indirect or consequential damages.
6. Termination. Either party may terminate upon thirty (30) days notice for material breach.
7. Governing Law. This Agreement shall be governed by the laws of the State of Delaware.
8. Miscellaneous. This Agreement constitutes the entire agreement between the parties and supersedes prior discussions.
"""
print('Loaded sample contract ({} chars)'.format(len(sample_contract)))
# Out:
# Loaded sample contract (1019 chars)

# %% [markdown]
# ## RecursiveCharacterTextSplitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=50,
    separators=["\n\n", "\n", " ", ""]
)
chunks = splitter.split_text(sample_contract)
print("RecursiveCharacterTextSplitter -> num chunks:", len(chunks))
for i,c in enumerate(chunks):
    print(f"--- chunk {i+1} (len={len(c)}) ---\n{c[:1000]}\n")
# Out:
# RecursiveCharacterTextSplitter -> num chunks: 4
# --- chunk 1 (len=17) ---
# SERVICE AGREEMENT
#
# --- chunk 2 (len=369) ---
# This Service Agreement ("Agreement") is made as of January 1, 2024, by and between Alpha Corp ("Provider") and Beta LLC ("Client").
# 1. Services. Provider shall provide software development services (the "Services") described in Schedule A.
# 2. Term. The term of this Agreement begins on the Effective Date and continues for twelve (12) months, unless earlier terminated.
#
# --- chunk 3 (len=326) ---
# 3. Payment. Client will pay Provider the fees set forth in Schedule B within thirty (30) days of invoice receipt.
# 4. Confidentiality. Each party shall maintain confidential information in strict confidence and not disclose it to third parties.
# 5. Liability. Neither party shall be liable for indirect or consequential damages.
#
# --- chunk 4 (len=301) ---
# 6. Termination. Either party may terminate upon thirty (30) days notice for material breach.
# 7. Governing Law. This Agreement shall be governed by the laws of the State of Delaware.
# 8. Miscellaneous. This Agreement constitutes the entire agreement between the parties and supersedes prior discussions.

# %% [markdown]
# ## CharacterTextSplitter

# %%
from langchain_text_splitters  import CharacterTextSplitter

char_splitter = CharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=40
)

char_chunks = char_splitter.split_text(sample_contract)

print("CharacterTextSplitter -> num chunks:", len(char_chunks))
for i,c in enumerate(char_chunks):
    print(f"--- chunk {i+1} (len={len(c)}) ---\n{c[:1000]}\n")
# Out:
# CharacterTextSplitter -> num chunks: 2
# --- chunk 1 (len=17) ---
# SERVICE AGREEMENT
#
# --- chunk 2 (len=998) ---
# This Service Agreement ("Agreement") is made as of January 1, 2024, by and between Alpha Corp ("Provider") and Beta LLC ("Client").
# 1. Services. Provider shall provide software development services (the "Services") described in Schedule A.
# 2. Term. The term of this Agreement begins on the Effective Date and continues for twelve (12) months, unless earlier terminated.
# 3. Payment. Client will pay Provider the fees set forth in Schedule B within thirty (30) days of invoice receipt.
# 4. Confidentiality. Each party shall maintain confidential information in strict confidence and not disclose it to third parties.
# 5. Liability. Neither party shall be liable for indirect or consequential damages.
# 6. Termination. Either party may terminate upon thirty (30) days notice for material breach.
# 7. Governing Law. This Agreement shall be governed by the laws of the State of Delaware.
# 8. Miscellaneous. This Agreement constitutes the entire agreement between the parties and supersedes prior discussions.

# %%
pip install --upgrade langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-text-splitters) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.12.0)
# Requirement already satisfied: certifi in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## TokenTextSplitter

# %%
from langchain_text_splitters import TokenTextSplitter

token_splitter = TokenTextSplitter(
    chunk_size=200,
    chunk_overlap=30
)

token_chunks = token_splitter.split_text(sample_contract)

print("TokenTextSplitter -> num chunks:", len(token_chunks))
for i, c in enumerate(token_chunks):
    print(f"--- chunk {i+1} (len={len(c)}) ---\n{c[:200]}\n")
# Out:
# TokenTextSplitter -> num chunks: 2
# --- chunk 1 (len=915) ---
#
# SERVICE AGREEMENT
#
# This Service Agreement ("Agreement") is made as of January 1, 2024, by and between Alpha Corp ("Provider") and Beta LLC ("Client").
# 1. Services. Provider shall provide software dev
#
# --- chunk 2 (len=238) ---
#  notice for material breach.
# 7. Governing Law. This Agreement shall be governed by the laws of the State of Delaware.
# 8. Miscellaneous. This Agreement constitutes the entire agreement between the part

# %% [markdown]
# ## SemanticChunker

# %%
pip install langchain-community langchain-experimental
# Out:
# Requirement already satisfied: langchain-community in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (0.4.1)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (1.1.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (0.4.56)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Downloading langchain_experimental-0.4.0-py3-none-any.whl (209 kB)
# Installing collected packages: langchain-experimental
# Successfully installed langchain-experimental-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Scematic Chucking > from langchain_experimental.text_splitter import SemanticChunker

# %%
pip install sentence-transformers langchain-huggingface
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-1.1.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting tqdm (from sentence-transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.9.1-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow (from sentence-transformers)
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Collecting filelock (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-huggingface) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.4.56)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.25.0)
# Requirement already satisfied: anyio in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (4.12.0)
# Requirement already satisfied: certifi in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.6.0)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.6-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from torch>=1.11.0->sentence-transformers)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\selvam sabarish\desktop\sabs\ai\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Downloading langchain_huggingface-1.1.0-py3-none-any.whl (29 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading torch-2.9.1-cp312-cp312-win_amd64.whl (110.9 MB)
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    -- ------------------------------------- 6.6/110.9 MB 36.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 13.1/110.9 MB 34.3 MB/s eta 0:00:03
#    ------- -------------------------------- 20.4/110.9 MB 34.0 MB/s eta 0:00:03
#    --------- ------------------------------ 26.5/110.9 MB 32.9 MB/s eta 0:00:03
#    ------------ --------------------------- 33.3/110.9 MB 32.0 MB/s eta 0:00:03
#    -------------- ------------------------- 41.2/110.9 MB 32.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 48.8/110.9 MB 33.4 MB/s eta 0:00:02
#    -------------------- ------------------- 56.4/110.9 MB 33.3 MB/s eta 0:00:02
#    --------------------- ------------------ 60.3/110.9 MB 31.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 63.4/110.9 MB 30.0 MB/s eta 0:00:02
#    ------------------------ --------------- 66.6/110.9 MB 28.5 MB/s eta 0:00:02
#    ------------------------ --------------- 69.2/110.9 MB 27.4 MB/s eta 0:00:02
#    ------------------------- -------------- 72.1/110.9 MB 26.3 MB/s eta 0:00:02
#    --------------------------- ------------ 75.5/110.9 MB 25.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 79.2/110.9 MB 25.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 83.1/110.9 MB 24.5 MB/s eta 0:00:02
#    ------------------------------- -------- 86.8/110.9 MB 24.1 MB/s eta 0:00:02
#    -------------------------------- ------- 91.0/110.9 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 95.2/110.9 MB 23.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 99.6/110.9 MB 23.6 MB/s eta 0:00:01
#    ------------------------------------ -- 104.6/110.9 MB 23.6 MB/s eta 0:00:01
#    --------------------------------------  109.8/110.9 MB 23.6 MB/s eta 0:00:01
#    ---------------------------------------- 110.9/110.9 MB 22.8 MB/s  0:00:04
# Using cached networkx-3.6-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl (8.7 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: mpmath, tqdm, threadpoolctl, sympy, setuptools, scipy, safetensors, Pillow, networkx, MarkupSafe, joblib, fsspec, filelock, scikit-learn, jinja2, huggingface-hub, torch, tokenizers, transformers, sentence-transformers, langchain-huggingface
#
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    ----------------------------------------  0/21 [mpmath]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    - --------------------------------------  1/21 [tqdm]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ----- ----------------------------------  3/21 [sympy]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    ------- --------------------------------  4/21 [setuptools]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    --------- ------------------------------  5/21 [scipy]
#    ----------- ----------------------------  6/21 [safetensors]
#    ----------- ----------------------------  6/21 [safetensors]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    ------------- --------------------------  7/21 [Pillow]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
#    --------------- ------------------------  8/21 [networkx]
# ...
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ---------------------------------- ----- 18/21 [transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    ------------------------------------ --- 19/21 [sentence-transformers]
#    -------------------------------------- - 20/21 [langchain-huggingface]
#    -------------------------------------- - 20/21 [langchain-huggingface]
#    ---------------------------------------- 21/21 [langchain-huggingface]
#
# Successfully installed MarkupSafe-3.0.3 Pillow-12.0.0 filelock-3.20.0 fsspec-2025.12.0 huggingface-hub-0.36.0 jinja2-3.1.6 joblib-1.5.2 langchain-huggingface-1.1.0 mpmath-1.3.0 networkx-3.6 safetensors-0.7.0 scikit-learn-1.7.2 scipy-1.16.3 sentence-transformers-5.1.2 setuptools-80.9.0 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.9.1 tqdm-4.67.1 transformers-4.57.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_huggingface import HuggingFaceEmbeddings

# ✅ Load a lightweight, FREE, open-source embedding model (runs on CPU)
embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2",  # or "BAAI/bge-small-en-v1.5"
    model_kwargs={"device": "cpu"},
    encode_kwargs={"normalize_embeddings": True}
)

# Create semantic splitter
semantic_splitter = SemanticChunker(
    embeddings,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=85  # adjust: higher = fewer chunks
)

# Your contract text
sample_contract = """
SERVICE AGREEMENT

This Service Agreement ("Agreement") is made as of January 1, 2024, by and between Alpha Corp ("Provider") and Beta LLC ("Client").
1. Services. Provider shall provide software development services (the "Services") described in Schedule A.
2. Term. The term of this Agreement begins on the Effective Date and continues for twelve (12) months, unless earlier terminated.
3. Payment. Client will pay Provider the fees set forth in Schedule B within thirty (30) days of invoice receipt.
4. Confidentiality. Each party shall maintain confidential information in strict confidence and not disclose it to third parties.
5. Liability. Neither party shall be liable for indirect or consequential damages.
6. Termination. Either party may terminate upon thirty (30) days notice for material breach.
7. Governing Law. This Agreement shall be governed by the laws of the State of Delaware.
8. Miscellaneous. This Agreement constitutes the entire agreement between the parties and supersedes prior discussions.

"""

# ✅ Semantic chunking — no internet, no API, no cost!
chunks = semantic_splitter.split_text(sample_contract)

print("\n=== Semantic Chunks (100% Local) ===")
for i, chunk in enumerate(chunks, 1):
    print(f"\n--- Chunk {i} ---\n{chunk.strip()}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[32], line 5
#       2 from langchain_huggingface import HuggingFaceEmbeddings
#       4 # ✅ Load a lightweight, FREE, open-source embedding model (runs on CPU)
# ----> 5 embeddings = HuggingFaceEmbeddings(
#       6     model_name="all-MiniLM-L6-v2",  # or "BAAI/bge-small-en-v1.5"
#       7     model_kwargs={"device": "cpu"},
#       8     encode_kwargs={"normalize_embeddings": True}
#       9 )
#      11 # Create semantic splitter
#      12 semantic_splitter = SemanticChunker(
#      13     embeddings,
#      14     breakpoint_threshold_type="percentile",
#      15     breakpoint_threshold_amount=85  # adjust: higher = fewer chunks
#      16 )
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#       5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\sentence_transformers\backend\load.py:7
#       4 import logging
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#      11 logger = logging.getLogger(__name__)
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)     36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)     37     "pyyaml",
#      38 ]
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)     43     "feature_extractor_*.py",
#      44 ]
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     289     # path/lib_folder/lib
#
# File c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\torch\__init__.py:264, in _load_dll_libraries()
#     260     err = ctypes.WinError(last_error)
#     261     err.strerror += (
#     262         f' Error loading "{dll}" or one of its dependencies.'
#     263     )
# --> 264     raise err
#     265 elif res is not None:
#     266     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\Selvam Sabarish\Desktop\sabs\AI\venv\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %% [markdown]
# ## Top 3 Practical Splitters for Real-World Use (Contracts focus)
#
# 1. **RecursiveCharacterTextSplitter** — *Top recommendation for contracts and PDFs.*
#    - Tries natural separators first (paragraphs, newlines) so clauses remain intact.
#    - Configurable separators and overlap to avoid cutting mid-clause.
#    - Works well when source has structured text and paragraphs.
#
# 2. **TokenTextSplitter** — *Critical when strict token budgets or exact token counts matter.*
#    - Splits by tokens (not characters), avoiding LLM input overflow.
#    - Recommended when you must precisely control tokens sent to the model (e.g., costly APIs).
#
# 3. **MarkdownHeaderTextSplitter** — *Excellent for docs with clear header structure.*
#    - Preserves header sections and is ideal for README, Notion-style docs, or structured legal notes with headings.
#
# **When CharacterTextSplitter is useful**: simple, fast baseline; but risks splitting in awkward places for legal clauses.

# %% [markdown]
# ## Practical tips to avoid broken clauses/context in contracts
#
# - Use **RecursiveCharacterTextSplitter** with separators prioritizing paragraph/newline boundaries.
# - Choose chunk_size large enough to contain full clauses (e.g., 400-800 characters) and chunk_overlap 50-150 to retain context across clause boundaries.
# - When in doubt, inspect the first 10 chunks to validate no clause was cut mid-sentence.
# - If precise token control is required for your LLM, post-process chunks with TokenTextSplitter to ensure token limits.
# - Consider hybrid approach: first recursive (structure-aware), then token-safety pass.

# %%
# Appendix: quick reference functions to get splitter objects
from langchain.text_splitter import (
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    MarkdownHeaderTextSplitter,
    TokenTextSplitter
)

def make_recursive_splitter(chunk_size=400, chunk_overlap=50):
    return RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap,
                                         separators=["\n\n", "\n", " ", ""])

def make_token_splitter(chunk_size=500, chunk_overlap=50):
    return TokenTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

def make_markdown_header_splitter(chunk_size=500, chunk_overlap=50):
    return MarkdownHeaderTextSplitter(headings=["#","##","###"], chunk_size=chunk_size, chunk_overlap=chunk_overlap)

print("Appendix splitters ready.")

# %% [markdown]
# ---
# **Saved notebook:** This notebook contains runnable code and explanatory markdown. Use it as a starting point for creating ingestion pipelines.
